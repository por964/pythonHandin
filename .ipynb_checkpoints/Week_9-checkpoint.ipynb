# %% [markdown]
# # Week 9 handin

# %% [markdown]
# #Ex 1, Programatically download the data from the above link.
# #Import the data into a Pandas dataframe.
# #Show the head of the Pandas dataframe.

# %%
# %matplotlib inline
# %matplotlib notebook
import pandas as pd
import numpy as np
import scipy.stats as stats
from sklearn import preprocessing

url = 'https://think.cs.vt.edu/corgis/datasets/csv/cars/cars.csv'

pd.set_option('display.max_rows', None)

data = pd.read_csv(url)

my_df = data[['Engine Information.Engine Statistics.Horsepower', 'Fuel Information.Highway mpg', 'Identification.Make',
              'Fuel Information.Fuel Type']]
my_df.columns = ['bhp','mpg','make','fuel']

df = my_df.loc[(my_df['make'] == 'BMW') & (my_df['fuel'] == 'Gasoline')].reset_index(drop=True)

df1 = df[['bhp', 'mpg']]
print(df1)
# Out:
#      bhp  mpg
# 0    555   17
# 1    555   17
# 2    555   17
# 3    555   17
# 4    300   26
# 5    300   26
# 6    300   28
# 7    300   26
# 8    300   26
# 9    300   28
# 10   320   26
# 11   300   28
# 12   300   25
# 13   300   26
# 14   300   26
# 15   300   25
# 16   300   27
# 17   300   28
# 18   320   26
# 19   300   26
# 20   300   28
# 21   300   26
# 22   300   25
# 23   265   36
# 24   300   25
# 25   300   26
# 26   265   36
# 27   300   27
# 28   300   28
# 29   300   26
# 30   300   28
# 31   300   25
# 32   360   23
# 33   300   25
# 34   360   22
# 35   300   26
# 36   300   26
# 37   360   22
# 38   400   22
# 39   300   30
# 40   300   28
# 41   400   25
# 42   300   24
# 43   300   23
# 44   300   28
# 45   400   22
# 46   400   22
# 47   400   22
# 48   400   22
# 49   300   27
# 50   300   30
# 51   360   21
# 52   360   22
# 53   400   22
# 54   400   21
# 55   400   20
# 56   400   20
# 57   535   19
# 58   400   21
# 59   400   22
# 60   400   20
# ...

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

df1.plot.scatter(x = 0, y = 1)

# %%
import matplotlib.pyplot as plt
c = df1.columns
d = preprocessing.normalize(df1)

normalized_df = pd.DataFrame(d, columns=c)
print(normalized_df.corr(method='pearson', min_periods=1))

normalized_df.plot.scatter(x = 1, y = 0)
plt.show()
# Out:
#           bhp       mpg
# bhp  1.000000 -0.979335
# mpg -0.979335  1.000000

# %%
xs = df1['bhp']
ys = df1['mpg']

xs_reshape = np.array(xs).reshape(-1, 1)
print(xs.shape)
print(xs_reshape.shape)
print(xs_reshape)

model = sklearn.linear_model.LinearRegression()
model.fit(xs_reshape, ys)
# Out:
# (198,)
# (198, 1)
# [[271]
#  [190]
#  [190]
#  [190]
#  [271]
#  [190]
#  [190]
#  [190]
#  [190]
#  [190]
#  [271]
#  [190]
#  [271]
#  [190]
#  [190]
#  [177]
#  [177]
#  [177]
#  [177]
#  [190]
#  [190]
#  [190]
#  [190]
#  [271]
#  [271]
#  [177]
#  [177]
#  [177]
#  [177]
#  [190]
#  [190]
#  [271]
#  [190]
#  [271]
#  [271]
#  [271]
#  [271]
#  [271]
#  [271]
#  [271]
#  [140]
#  [140]
#  [140]
#  [140]
#  [140]
#  [140]
#  [140]
#  [197]
#  [140]
#  [140]
#  [140]
#  [140]
#  [140]
#  [140]
#  [140]
#  [140]
#  [197]
#  [140]
#  [140]
#  [140]
#  [140]
#  [140]
#  [140]
#  [140]
#  [140]
#  [140]
#  [140]
#  [140]
#  [140]
#  [197]
#  [140]
#  [140]
#  [140]
#  [140]
#  [140]
#  [140]
#  [140]
#  [140]
#  [140]
#  [140]
#  [140]
#  [197]
#  [122]
#  [122]
#  [117]
#  [117]
#  [117]
#  [117]
#  [117]
#  [117]
#  [117]
#  [117]
#  [180]
#  [180]
#  [180]
#  [180]
#  [180]
#  [180]
#  [180]
#  [180]
#  [180]
#  [180]
#  [180]
#  [180]
#  [180]
#  [180]
#  [166]
#  [166]
# ...

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [-0.07521521]
# 44.568070680829294

# %% [markdown]
# ## Perform linear regression where x = horsepower and y = mpg

# %%
z_scores = stats.zscore(df1)
abs_z_scores = np.abs(z_scores)
filtered_entries = (abs_z_scores < 3).all(axis=1)
df2 = df1[filtered_entries]


print(df2.columns)
print(df2.info())
print('--------------')
#print(df2['bhp'].min())
#print(df2['bhp'].max())
#print(df2['mpg'].min())
#print(df2['mpg'].max())

scaler = preprocessing.MinMaxScaler()
cars = df2.columns
d = scaler.fit_transform(df2)
scaled_df = pd.DataFrame(d, columns=cars)
print(scaled_df.head())
print(scaled_df.tail())
#print(df2)
print(scaled_df)
# Out:
# Index(['bhp', 'mpg'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 132 entries, 0 to 131
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   bhp     132 non-null    int64
#  1   mpg     132 non-null    int64
# dtypes: int64(2)
# memory usage: 3.1 KB
# None
# --------------
#         bhp       mpg
# 0  1.000000  0.000000
# 1  1.000000  0.000000
# 2  1.000000  0.000000
# 3  1.000000  0.000000
# 4  0.190476  0.473684
#           bhp       mpg
# 127  0.507937  0.263158
# 128  0.507937  0.315789
# 129  0.507937  0.157895
# 130  0.238095  0.421053
# 131  0.238095  0.421053
#           bhp       mpg
# 0    1.000000  0.000000
# 1    1.000000  0.000000
# 2    1.000000  0.000000
# 3    1.000000  0.000000
# 4    0.190476  0.473684
# 5    0.190476  0.473684
# 6    0.190476  0.578947
# 7    0.190476  0.473684
# 8    0.190476  0.473684
# 9    0.190476  0.578947
# 10   0.253968  0.473684
# ...

# %%
# Out:
# (198,)
# (198, 1)
# [[1.        ]
#  [0.47402597]
#  [0.47402597]
#  [0.47402597]
#  [1.        ]
#  [0.47402597]
#  [0.47402597]
#  [0.47402597]
#  [0.47402597]
#  [0.47402597]
#  [1.        ]
#  [0.47402597]
#  [1.        ]
#  [0.47402597]
#  [0.47402597]
#  [0.38961039]
#  [0.38961039]
#  [0.38961039]
#  [0.38961039]
#  [0.47402597]
#  [0.47402597]
#  [0.47402597]
#  [0.47402597]
#  [1.        ]
#  [1.        ]
#  [0.38961039]
#  [0.38961039]
#  [0.38961039]
#  [0.38961039]
#  [0.47402597]
#  [0.47402597]
#  [1.        ]
#  [0.47402597]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.14935065]
#  [0.14935065]
#  [0.14935065]
#  [0.14935065]
#  [0.14935065]
#  [0.14935065]
#  [0.14935065]
#  [0.51948052]
#  [0.14935065]
#  [0.14935065]
#  [0.14935065]
#  [0.14935065]
#  [0.14935065]
#  [0.14935065]
#  [0.14935065]
#  [0.14935065]
#  [0.51948052]
#  [0.14935065]
#  [0.14935065]
#  [0.14935065]
#  [0.14935065]
# ...

# %%
model = sklearn.linear_model.LinearRegression()
model.fit(xs_reshape, ys)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [-0.55157822]
# 0.7508519499437643

# %%
predicted = model.predict(xs_reshape)
one_bhp = model.predict([[1]])
print('Having 1 bhp will result in mpg: {}'.format(one_bhp[0]))
predicted
# Out:
# Having 1 bhp will result in mpg: 44.49285546944459
# array([24.1847484 , 30.27718052, 30.27718052, 30.27718052, 24.1847484 ,
#        30.27718052, 30.27718052, 30.27718052, 30.27718052, 30.27718052,
#        24.1847484 , 30.27718052, 24.1847484 , 30.27718052, 30.27718052,
#        31.25497827, 31.25497827, 31.25497827, 31.25497827, 30.27718052,
#        30.27718052, 30.27718052, 30.27718052, 24.1847484 , 24.1847484 ,
#        31.25497827, 31.25497827, 31.25497827, 31.25497827, 30.27718052,
#        30.27718052, 24.1847484 , 30.27718052, 24.1847484 , 24.1847484 ,
#        24.1847484 , 24.1847484 , 24.1847484 , 24.1847484 , 24.1847484 ,
#        34.03794109, 34.03794109, 34.03794109, 34.03794109, 34.03794109,
#        34.03794109, 34.03794109, 29.75067404, 34.03794109, 34.03794109,
#        34.03794109, 34.03794109, 34.03794109, 34.03794109, 34.03794109,
#        34.03794109, 29.75067404, 34.03794109, 34.03794109, 34.03794109,
# ...

# %%
import sklearn.linear_model

xs = scaled_df['bhp']
ys = scaled_df['mpg']

xs_reshape = np.array(xs).reshape(-1, 1)
print(xs.shape)
print(xs_reshape.shape)
print(xs_reshape)
# Out:
# (132,)
# (132, 1)
# [[1.        ]
#  [1.        ]
#  [1.        ]
#  [1.        ]
#  [0.19047619]
#  [0.19047619]
#  [0.19047619]
#  [0.19047619]
#  [0.19047619]
#  [0.19047619]
#  [0.25396825]
#  [0.19047619]
#  [0.19047619]
#  [0.19047619]
#  [0.19047619]
#  [0.19047619]
#  [0.19047619]
#  [0.19047619]
#  [0.25396825]
#  [0.19047619]
#  [0.19047619]
#  [0.19047619]
#  [0.19047619]
#  [0.07936508]
#  [0.19047619]
#  [0.19047619]
#  [0.07936508]
#  [0.19047619]
#  [0.19047619]
#  [0.19047619]
#  [0.19047619]
#  [0.19047619]
#  [0.38095238]
#  [0.19047619]
#  [0.38095238]
#  [0.19047619]
#  [0.19047619]
#  [0.38095238]
#  [0.50793651]
#  [0.19047619]
#  [0.19047619]
#  [0.50793651]
#  [0.19047619]
#  [0.19047619]
#  [0.19047619]
#  [0.50793651]
#  [0.50793651]
#  [0.50793651]
#  [0.50793651]
#  [0.19047619]
#  [0.19047619]
#  [0.38095238]
#  [0.38095238]
#  [0.50793651]
#  [0.50793651]
#  [0.50793651]
#  [0.50793651]
#  [0.93650794]
#  [0.50793651]
#  [0.50793651]
#  [0.50793651]
# ...

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

url = 'https://think.cs.vt.edu/corgis/datasets/csv/cars/cars.csv'

pd.set_option('display.max_rows', None)

data = pd.read_csv(url)

my_df = data[['Engine Information.Engine Statistics.Horsepower', 'Fuel Information.Highway mpg', 'Identification.Make',
              'Fuel Information.Fuel Type']]
my_df.columns = ['bhp','mpg','make','fuel']

df = my_df.loc[(my_df['fuel'] == 'Gasoline')].reset_index(drop=True)

df1 = df[['bhp', 'mpg']]
#print(df1.head)

z_scores = stats.zscore(df1)
abs_z_scores = np.abs(z_scores)
filtered_entries = (abs_z_scores < 3).all(axis=1)
df2 = df1[filtered_entries]

df2.plot(kind='scatter', x='bhp', y='mpg')
#plt.show()
#Test train split for supervised training
X_train, X_test, y_train, y_test = train_test_split(df2.bhp, df2.mpg)
#Test train split visualization
plt.scatter(X_train, y_train, label='Training data', color='r', alpha=.7)
plt.scatter(X_test, y_test, label='Testing data', color='g', alpha=.7)
plt.legend()
plt.title('Test Train Split')
plt.show()

#create linear model and train it
LR = LinearRegression()
LR.fit(X_train.values.reshape(-1,1), y_train.values)

#use model to predict on TEST data
prediction = LR.predict(X_test.values.reshape(-1,1))

#Plot prediction line against actual test data
plt.plot(X_test, prediction, label='Linear regression', color='b')
plt.scatter(X_test, y_test, label='Actual test data', color='g', alpha=.7)
plt.legend()
plt.show()

#Predict MPG for a car with 670 bhp
my_prediction = LR.predict(np.array([[670]]))[0]
print('A car with 670 bhp is predicted to have a mpg of: {}'.format(my_prediction))
#Score this model
print(LR.score(X_test.values.reshape(-1,1), y_test.values))

print('Model coefficient: {}'.format(LR.coef_))
# Out:
# A car with 670 bhp is predicted to have a mpg of: 10.182637862213245
# 0.40966697543162967
# Model coefficient: [-0.03627042]
